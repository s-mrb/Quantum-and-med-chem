# %% [markdown]
# # Conda setup

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !time bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2020-06-08 12:47:24--  https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh [following]
# --2020-06-08 12:47:24--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  81.12M   249MB/s    in 0.3s
#
# ...

# %% [markdown]
# # Packages installation

# %%
# !time conda install -q -y -c openbabel openbabel
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - openbabel
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     cairo-1.14.12              |       h8948797_3         906 KB
#     certifi-2020.4.5.1         |           py37_0         155 KB
#     conda-4.8.3                |           py37_0         2.8 MB
#     fontconfig-2.13.0          |       h9420a91_0         227 KB
#     freetype-2.9.1             |       h8a8886c_1         550 KB
#     glib-2.63.1                |       h5a9c865_0         2.9 MB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libuuid-1.0.3              |       h1bed415_2          15 KB
# ...

# %% [markdown]
# # Set Path Variable

# %%
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# %% [markdown]
# # Make imports

# %%
import openbabel
import pybel
from pybel import Outputfile
from pybel import readfile

# below import can give error
# from cairosvg import svg2png

# below also don't work
# import cairosvg
# from cairosvg import svg2png

# still dont work, use pip

# !pip install cairosvg
from cairosvg import svg2png
# Out:
# ...
#      |████████████████████████████████| 50 kB 2.3 MB/s
# ...
#      |████████████████████████████████| 68 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 61 kB 128 kB/s
# ...
#      |████████████████████████████████| 2.1 MB 49.4 MB/s
# ...
#   Created wheel for cairocffi: filename=cairocffi-1.1.0-py3-none-any.whl size=88588 sha256=3d0d34f6314b6711dabd4bf8aae5e030eaf368629971fddea5f8568ad31985a6
#   Stored in directory: /root/.cache/pip/wheels/04/7d/d9/68956b3da44dbef65b150faff8a9810209588de332ebe1fa63
# Successfully built cairocffi
# ...

# %% [markdown]
# **Note :**
#
#
#      if you installed openbabel, then cairosvg automatically gets insalled,
#      as   it is one of the dependency.
#
#      You can not now just say, *from cairosvg import svg2png*.
#      First import cairosvg from installed packages then say
#      *from cairosvg   import svg2png*
#
#   It is possible that it still dont works, then use *!pip to insatll cairosvg*

# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Keep notebook active by JS code that keeps clicking notebook

# %% [markdown]
# Run below code in console of browser
#
#        function ClickConnect(){
#        console.log("Working");
#        document.querySelector("colab-toolbar-button").click()
#         }setInterval(ClickConnect,60000)
#
#
# OR
#
#
#         function ConnectButton(){
#             console.log("Connect pushed");
#             document.querySelector("#top-toolbar > colab-connect-button").
#                shadowRoot.querySelector("#connect").click()
#         }
#         setInterval(ConnectButton,60000);

# %% [markdown]
# # Data Download![alt text](https://)

# %% [markdown]
# ### Path

# %%
# variables setup
url1 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_01.zip"
url2 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_02.zip"
url3 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_03.zip"
url4 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_04.zip"
url5 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_05.zip"
url6 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_06.zip"
url7 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_07.zip"
url8 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_08.zip"
url9 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_09.zip"
url10 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_10.zip"
url11 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_11.zip"
url12 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_12.zip"
url13 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_13.zip"
url14 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_14.zip"
url15 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_15.zip"
url16 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_16.zip"
url17 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_17.zip"
url18 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_18.zip"
url19 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_19.zip"
url20 = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_20.zip"





url_list = [url1,url2]
where_to_store = "/content/drive/My Drive/DataSets/Chemistry/enamine/dwnload"

# %%
download(url_list,where_to_store)  



# Below block for sound 
# import time
# from google.colab import output
# t_end = time.time() + 60 * 0.5
# while time.time() < t_end:
#   output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')




# OR

# Play sound once finished
from IPython.display import Audio
audio_path = "/content/audio"
name_of_sound = "a.mp3"
audio_url = "http://nl02.mp3pro.xyz/811b85615a78e38a70752/In%20The%20Mood%20For%20Love%20-%20Yumeji%20s%20Theme.mp3"
Audio(get_path2audio(name="a.mp3",audio_directory=audio_path,audio_url=audio_url), autoplay=True)

# %% [markdown]
# ### download

# %%
# now download data
# !wget "$url" -P "$where_to_store"


# Make sound once finished
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
# --2020-06-08 05:29:41--  https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_01.zip
# Resolving enamine.net (enamine.net)... 159.89.190.43
# Connecting to enamine.net (enamine.net)|159.89.190.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1743773229 (1.6G) [application/zip]
# Saving to: ‘/content/drive/My Drive/DataSets/Chemistry/enamine/dwnload/Enamine_REAL_full_smiles_Part_01.zip’
#
# Enamine_REAL_full_s 100%[===================>]   1.62G  45.6MB/s    in 37s
#
# 2020-06-08 05:30:18 (44.7 MB/s) - ‘/content/drive/My Drive/DataSets/Chemistry/enamine/dwnload/Enamine_REAL_full_smiles_Part_01.zip’ saved [1743773229/1743773229]

# %% [markdown]
# # Unzip downloaded data

# %% [markdown]
# ### Path Setup

# %%
# variable setup
# absolute path, uptill extension
zip_file_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/dwnload/Enamine_REAL_full_smiles_Part_01.zip"

# just folder absolute path
where_to_unzip = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip"

# %% [markdown]
# ### Unzip

# %%
# now unzip
# !unzip -uq "$zip_file_path" -d "$where_to_unzip"

# Make sound once finished
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %% [markdown]
# # Peek extracted files

# %%
import sys
file_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip/2019q3-4_Enamine_REAL_1.2B_SMILES_Part_01.smiles"

line_no = 0
with open(file_path, 'r') as f:
  for line in f:
    print(line)
    line_no += 1
    if line_no == 50:
      sys.exit()

# %% [markdown]
# ### Observation

# %% [markdown]
# **if you find header, then it must be removed**
#
# First remove header and see whether obabel works on it wihtout any processing on it

# %% [markdown]
# ### Testing direct obabel on removed header huge file

# %%
# variabel setup 
# make sure every path vends with /, if not file
out_smiles_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/smiles/one/"
in_smile_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip/one.smiles"

out_file_name = "one.smi"
 
full_out_smiles_path = out_smiles_path + out_file_name



# first lets check whether can obabel make svg without changing smiles file
out_svg_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/r_obabel/one/"

out_file = Outputfile("svg", out_svg_path + "one.svg")

header = True
for mol in readfile("smi", in_smile_path):

  if header:
    header = False
    continue

  out_file.write(mol)
    
out_file.close()


# Make sound once finished
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %% [markdown]
# # Get only smiles files

# %% [markdown]
# **Parse extracted file, present format might not be usable**
#
# Parse according to ur downloaded smiles files structures, sometimes there won't be any need for doing any pre-processing and you can just feed it to svg maker, All smiles files have smiles in start of line, if parsing is needed just get first string of each line

# %%
# variabel setup 
# make sure every path vends with /, if not file
out_smiles_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/smiles/one/"
in_smiles_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip/one.smiles"

out_file_name = "one.smi"
out_smiles_abs_path = out_smiles_path + out_file_name


dir_check(out_smiles_path)
file_if_not(full_out_smile_path)


with open(in_smiles_path,'r') as r:
  with open(out_smiles_abs_path,'w') as o:
    next(r)
    for line in r:
      o.write(line.split()[0]+"\n")



# Make sound once finished
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %% [markdown]
# **Test new file**

# %%
import sys
read_path = out_smiles_abs_path


line_counter = 0
with open (read_path,'r') as f:
  for line in f:
    print(line)
    line_counter += 1

    if line_counter == 500:
      sys.exit()

# %% [markdown]
# # Check whether huge "only smiles" file can be feeded to obabel

# %%
# first lets check whether can obabel make svg without changing smiles file
in_smiles_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip/one.smiles"
out_svg_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/r_obabel/one/"
out_svg_name = "one.svg"

svg_abs_path = out_svg_path + out_svg_name
out_file = Outputfile("svg", out_svg_path + "one.svg")

header = True
for mol in readfile("smi", in_smile_path):
  out_file.write(mol)
    
out_file.close()


# Make sound once finished
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %% [markdown]
# ***Checking unix command***

# %%
file_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip/one.smiles"
out_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/r_obabel/one/"
name = "one.svg"

full_p = out_path + name

# !babel -ismi "$file_path" -osvg out_path


# Make sound once finished
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %% [markdown]
# # Split huge only smiles file

# %% [markdown]
# ### Copy from drive

# %%
# !cp "/content/drive/My Drive/DataSets/Chemistry/enamine/root/smiles/aha/one.smi" "/content/smiles/one"


# Make sound once finished
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %% [markdown]
# ### Feed to splitter

# %% [markdown]
# **Code for converting smiles huge file to svg via ***feed_png_maker*** takes considerable time...so better to split files into chunks using splitter**

# %%
huge_files_folder = "/content/smiles"
root = "/content/drive/My Drive/DataSets/Chemistry/enamine/root"
feed_splitter(huge_files_folder,root)



# Make sound once finished
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %% [markdown]
# # Test Pipeline

# %% [markdown]
# ### Feeding

# %%
root = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/"
# feed_smiles(root)
# feed_parser(root)
feed_png_maker(root)


# make sound once finished
while True:
  from google.colab import output
  output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %% [markdown]
# ### Testing

# %%
location = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/p_obabel/one/1212.smi"
import sys

line_no = 0
with open (location, 'r') as r:
  for line in r:
    print(line)
    line_no += 1

    if line_no == 500:
      sys.exit()

# %% [markdown]
# ### Count total files in drive

# %%
folder = '/content/drive/My Drive/DataSets/Chemistry/obabel2png/r_png/gdb_11'
files = []
for all in walk(folder):
  files.extend(all)

# print(files)
print(len(files[2]))

# %% [markdown]
# # Methods for comfort

# %%
def get_path2audio(**kwargs):
# name, audio_directory and audio_url
  audio_d = None
  if "audio_directory" in kwargs:
      audio_d = kwargs["audio_directory"]
  else:
      print("Please give directory (as string) where to store file, directory will be created automatically if do not exist")
      return
  if audio_d[-1] != "/":
      audio_d = audio_d + '/'
  dir_check(audio_d)
  

  #if len 1 then user passed name
  if "audio_url" in kwargs:
    if "name" in kwargs:
      name_of_file_to_play = kwargs["name"]
      
    else:
      print("Please give name of file, this name will be used for naming downloaded file..no spaces!!")
      return
    
    audio_url = kwargs["audio_url"]
    # !wget -O "$audio_d$name_of_file_to_play" "$audio_url"
    
    abs_file_path = audio_d + name_of_file_to_play
    return abs_file_path
  elif len(kwargs) == 2:
    if "name" in kwargs:
      name_of_file_to_play = kwargs["name"]
      
    else:
      print("Please give name of file, this name will be used for naming downloaded file..no spaces!!")
      return
    abs_file_path = audio_d + name_of_file_to_play
    audio_files = getF(audio_d,"files")
    for f in audio_files:
      if f==name_of_file_to_play:
        return abs_file_path
    print("File with given name do not exist!!")
  elif len(kwargs) == 1:
    audio_files = getF(audio_d,"files")
    if len(audio_files)==0:
      print("directory empty!!")
      return
    abs_file_path = audio_d + audio_files[0]
    return abs_file_path + audio_files[0]

# %%
from IPython.display import Audio
audio_path = "/content/audio"
name_of_sound = "a.mp3"
url = "http://nl02.mp3pro.xyz/811b85615a78e38a70752/In%20The%20Mood%20For%20Love%20-%20Yumeji%20s%20Theme.mp3"
# get_path2audio(name="a.mp3",audio_directory=audio_path)
Audio(get_path2audio(name="a.mp3",audio_directory=audio_path,audio_url=url), autoplay=True)

# %% [markdown]
# # All the functional Methods

# %% [markdown]
# ***NOTE:***
#
#       In local PC path convention differs from that of colab,  / vs \

# %%
import ntpath
from os import walk, path
from pathlib import Path
import os
import sys



# make a download method
def download(url, output_path):
  if (output_path[-1] != "/"):
    output_path = output_path + "/"
  dir_check(output_path)
  if isinstance(url, str):
    # !wget "$url" -P "$output_path"
    re = "Successfully downloaded in following directory: "+"\n"+output_path
    return re
  
  for link in url:
    # !wget "$link" -P "$output_path"

# integrate feed_obabel with rest of the pipeline
def feed_obabel(in_smile_path,out_svg_path):
  out_file = Outputfile("svg", out_svg_path)
  for mol in readfile("smi", in_smile_path):
    out_file.write(mol)
    
  out_file.close()




# define smiles feeder

def feed_smiles(root):

    if root[-1] != "/":
      root += "/"
    folders = getF(root, "folders")


    # g = getF(root + "\\" + folders[2])

    if len(folders) == 0:
        raise Exception("Empty directory!")

    if len(folders) == 1:
        raise Exception("One folders missing!")

    if len(folders) == 2:
        raise Exception("Two folders missing!")
    if len(folders) == 3:
        raise Exception("Three folders missing!")

    r_obabel = ""
    r_png = ""
    p_obabel = ""
    smiles = ""

    flag = {"r_obabel": 0, "p_obabel": 0, "r_png": 0, "smiles":0}

    for f in folders:
        if f == "r_obabel":
            r_obabel = root + f + "/"
            flag["r_obabel"] = 1
        if f == "p_obabel":
            p_obabel = root + f + "/"
            flag["p_obabel"] = 1
        if f == "r_png":
            r_png = root + f + "/"
            flag["r_png"] = 1
        if f == "smiles":
            smiles = root + f + "/"
            flag["smiles"] = 1
        

    labels = list(flag.values())

    name = ""

    if not labels[0]:
        raise Exception("r_obabel folder not named properly!")
    if not labels[1]:
        raise Exception("p_obabel folder not named properly!")
    if not labels[2]:
        raise Exception("r_png folder not named properly")
    if not labels[3]:
        raise Exception("smiles folder not named properly")

    # Reading smiles directory

    smiles_folders = getF(smiles, "folders")

    # Read
    for fol in smiles_folders:

        # current folder address
        current_folder_dir = smiles + fol + "/"

        # corresponding out folder for this folder
        corr_out_folder_dir = r_obabel + fol + "/"

        # files in current folder
        
        files = getF(current_folder_dir, "files")
    

        # do parsing of each file
        for fil in files:

            # complete path of current file
            file_path = current_folder_dir + fil

            dir_check(corr_out_folder_dir)

            # corresponding out file path
            # before passing file to parser make output folder if don't exist
            out_path = corr_out_folder_dir + fil

            # read log
            # if logs folder not present then make one
            dir_check(root + "logs" + "/" + "smiles_feeder/")
            logs_path = root + "logs" + "/" + "smiles_feeder" + "/" + "sf_logs.txt"
            file_if_not(logs_path)
            logs_dict = read_dict(logs_path)

            # call feed_obabel for this file only if it is not feeded already

            # if folder is in logs file
            # flag for file presence
            file_present = False

            if fol in logs_dict:
                # check whether file(i) is in it or not
                for i in logs_dict[fol]:
                    # if file found then continue
                    if i == fil:
                        file_present = True
                        continue
                if not file_present:
                    feed_obabel(file_path, out_path)
                    # after smiles2svg done, record in logs
                    ap_dict(logs_path, fol, fil, 1)
            else:
                # print("folder not there")
                feed_obabel(file_path, out_path)
                ap_dict(logs_path, fol, fil, 0)





def dir_check(path):
    Path(path).mkdir(parents=True, exist_ok=True)

# 2nd way
# def dir_check(path):
#     if not os.path.exists(path):
#         os.makedirs(path)


# here read_dict is used to read log files, make sure to keep all logs
# with same format so that you can reuse this function
def read_dict(path):
    dic = {}
    with open(path,'r') as f:
        key = ""
        for line in f:
            if line[0:5] == "_key_":
                key = (line.split())[1]
            else:
                temp = {key:line.split()}
                dic.update(temp)
        return dic

    # for line in file:
    #     line_offset.append(offset)
    #     offset += len(line)


def get_append_pos(path, key):
    with open(path,'r') as f:
        while True:
            # read line and move cursor to start of next line, but could be read in next while loop!!
            line = f.readline()

            if line == '':
                break
            if line[0:5] == "_key_":
                if (line.split())[1] == key:
                    # move cursor to start of **line after next line**,
                    # print()
                    f.readline()

                    # Why -1 works????
                    #
                    # The newline character is a single(typically 8 - bit) character.It's represented in program source
                    # (either in a character literal or in a string literal) by the two-character sequence \n . So '\n
                    # ' is a character constant representing a single character, the newline character

                    return f.tell() - 1
    return


def ap_dict(path, key, value, folder):
    # folder is boolean, 0 if key absent else 1
    if folder == 0:
        with open(path, 'a') as f:
            f.write("\n_key_ " + key + "\n" + value +" ")
            return
    pos = get_append_pos(path, key)

    c_last = ""

    with open (path, 'r') as f:
        f.seek(pos)
        c_last = f.read()

    # Note you can not use append below because
    # cause if first time if it is
    # _key_   gdb_11_2
    # gdb_11_2.txt
    #
    # then second time it will be
    # gdb_11_2.txt    gdb_11_3.txt    gdb_11_2.txt
    #
    # Why, because you r keeping line number to copy rest but using seek to write, so if you want to use append
    # then keep record of posiiton of index where to append
    #
    with open(path, 'a') as f:

        f.seek(pos)
        f.write(value + " " + c_last)



def file_if_not(p):
    if not os.path.exists(p):
        open(p, 'a').close()


def getF(directory, x="both"):
    # x could be "files" or "folders" or "both"

    folders = []
    for f in walk(directory):
        folders.extend(f)

    if x == "folders":
      return folders[1]

      
      
        
    if x == "files":
        return folders[2]
    else:
      return folders[1], folders[2]

      
        
        


def path_leaf(path):
    head, tail = ntpath.split(path)

    # if name ends with \\ then tail won't return anything
    # return tail or ntpath.basename(head)

    # since you dont want to return in case its not file
    return tail

def parse_r_obabel(read_path, write_path):
    # Parser for babel svg

    # NOTE below string also include \n, to add \n at end you must enter on last line
    start = """<svg version="1.1" id="topsvg"
    xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
    xmlns:cml="http://www.xml-cml.org/schema" x="0" y="0" width="256" height="256" viewBox="0 0 100 100">
    <title> - Open Babel Depiction</title>
    <rect x="0" y="0" width="100" height="100" fill="white"/>
    <g transform="translate(0,0)">
    """

    fil = 'fill="rgb(0,0,0)"'
    strke = 'stroke="rgb(0,0,0)"'
    strke_width = 'stroke-width="1"'

    # NOTE : anything added to above str is added on new line



    st = ""
    out = ""
    smile_done = False
    end = False
    finish = False
    space = " "
    width = 'width="100"'
    height = 'height="100"'

    test_c = 0
    dim_flag = False
    b_check = False
    s_check = False
    mol_no = 1
    
    file = path_leaf(read_path)

    with open(read_path, 'r', encoding="utf-8") as f:
        for i in range(1):
            next(f)
        for line in f:
            if line[1:5] == "?xml":
              continue

            if line[1:12] == "svg version":
                for i in range(5):
                    next(f)
                continue
            if line[0:4] == "</g>" or end:

                end = True

                line_split = line.split()
                for token in line_split:
                    if token[0] == ">":
                        # id = "db: " + file + " id: " + token[1:]
                        idd = "db: " + file + " id: " + str(mol_no)
                        mol_no+=1
                        st = st + "</g>" + "\n" + "</svg>" + "\n"
                        st = idd + "\n" + '"""' + "\n" + start + st + '"""' + "\n"
                        out = out + st
                        st = ""
                        smile_done = True
                        end = False

            if end:
                continue

            if smile_done:
                if not end:
                    smile_done = False
                    finish = True
                    continue
            if finish:
                finish = False

                continue

            token_list = []
            for s in line.split():
                if s[-1] == ">":
                    b_check = True

                if (2 <= len(s)):
                    if s[-2] == "/":
                        s_check = True

                if s[0:6] == "width=":
                    s = width
                if s[0:7] == "height=":
                    s = height
                if s[0:7] == "stroke=":
                    s = strke
                if s[0:13] == "stroke-width=":
                    s = strke_width
                if s[0:5] == "fill=":
                    s = fil
                if b_check:
                    b_check = False
                    if s_check:
                        s_check = False
                        if s[-2] != "/":
                            s = s + "/>"
                    elif s[-1] != ">":
                        s = s + ">"

                token_list.append(s)

            temp = ""
            for t in range(len(token_list) - 1):
                temp += token_list[t] + " "

            # sometimes list will  be empty
            if token_list:
                temp += token_list[-1] + "\n"

            token_list = []

            st = st + temp

    with open(write_path, 'w') as f:
        f.write(out)

# parse raw svg of obabel into form receivable to svg2png converter
def feed_parser(root):

    if root[-1] != "/":
      root += "/"
    folders = getF(root, "folders")


    # g = getF(root + "\\" + folders[2])

    if len(folders) == 0:
        raise Exception("Empty directory!")

    if len(folders) == 1:
        raise Exception("One folders missing!")

    if len(folders) == 2:
        raise Exception("Two folders missing!")
    if len(folders) == 3:
        raise Exception("Three folders missing!")

    r_obabel = ""
    r_png = ""
    p_obabel = ""
    smiles = ""

    flag = {"r_obabel": 0, "p_obabel": 0, "r_png": 0, "smiles":0}

    for f in folders:
        if f == "r_obabel":
            r_obabel = root + f + "/"
            flag["r_obabel"] = 1
        if f == "p_obabel":
            p_obabel = root + f + "/"
            flag["p_obabel"] = 1
        if f == "r_png":
            r_png = root + f + "/"
            flag["r_png"] = 1
        if f == "smiles":
            smiles = root + f + "/"
            flag["smiles"] = 1           

        

    labels = list(flag.values())

    name = ""

    if not labels[0]:
        raise Exception("r_obabel folder not named properly!")
    if not labels[1]:
        raise Exception("p_obabel folder not named properly!")
    if not labels[2]:
        raise Exception("r_png folder not named properly")
    if not labels[3]:
        raise Exception("smiles folder not named properly")

    # Reading r_obabel

    r_obabel_folders = getF(r_obabel, "folders")

    # Read
    for fol in r_obabel_folders:

        # current folder address
        current_folder_dir = r_obabel + fol + "/"

        # corresponding out folder for this folder
        corr_out_folder_dir = p_obabel + fol + "/"

        # files in current folder
        
        files = getF(current_folder_dir, "files")
    

        # do parsing of each file
        for fil in files:

            # complete path of current file
            file_path = current_folder_dir + fil

            dir_check(corr_out_folder_dir)

            # corresponding out file path
            # before passing file to parser make output folder if don't exist
            out_path = corr_out_folder_dir + fil

            # read log
            # if logs folder not present then make one
            dir_check(root + "logs" + "/" + "parser/")
            logs_path = root + "logs" + "/" + "parser" + "/" + "p_logs.txt"
            file_if_not(logs_path)
            logs_dict = read_dict(logs_path)

            # call parser for this file only if it is not parsed already
            # parser
            # if folder is in logs file
            # flag for file presence
            file_present = False

            if fol in logs_dict:
                # check whether file(i) is in it or not
                for i in logs_dict[fol]:
                    # if file found then continue
                    if i == fil:
                        file_present = True
                        continue
                if not file_present:
                    parse_r_obabel(file_path, out_path)
                    # after parsing done, record in logs
                    ap_dict(logs_path, fol, fil, 1)
            else:
                # print("folder not there")
                parse_r_obabel(file_path, out_path)
                ap_dict(logs_path, fol, fil, 0)






def png_maker(current_file_path, cor_out_folder):
  
    input = current_file_path

    name = ""
    code = ""
    code_flag = False

    with open(current_file_path, 'r') as smiles:
        for line in smiles:
            if line[0:3] == "db:":
                tok = line.split()
                db = tok[1].split('.')[0]
                no = tok[3]
                name = db + "_" + no
                continue

            if line[0:3] == '"""':
                if code_flag:
                    code_flag = False

                    dir_check(cor_out_folder)
                    print(code)
                    # ???
                    svg2png(bytestring=code,
                            write_to=cor_out_folder + name + ".png")

                    code = ""
                    name = ""
                    continue

            if line[0:3] == '"""':
                code_flag = True
                continue

            if code_flag:
                code += line




def feed_png_maker(root):

    if root[-1] != "/":
      root += "/"
    folders = getF(root, "folders")
    g = getF(root + "/" + folders[2])

    if len(folders) == 0:
        raise Exception("Empty directory!")

    if len(folders) == 1:
        raise Exception("Three folders missing!")

    if len(folders) == 2:
        raise Exception("two folders missing!")
    if len(folders) == 3:
        raise Exception("One folders missing!")

    r_obabel = ""
    r_png = ""
    p_obabel = ""
    smiles = ""

    flag = {"r_obabel": 0, "p_obabel": 0, "r_png": 0, "smiles":0}

    for f in folders:
        if f == "r_obabel":
            r_obabel = root + f + "/"
            flag["r_obabel"] = 1
        if f == "p_obabel":
            p_obabel = root + f + "/"
            flag["p_obabel"] = 1
        if f == "r_png":
            r_png = root + f + "/"
            flag["r_png"] = 1
        if f == "smiles":
            smiles = root + f + "/"
            flag["smiles"] = 1


    labels = list(flag.values())

    name = ""

    if not labels[0]:
        raise Exception("r_obabel folder not named properly!")
    if not labels[1]:
        raise Exception("p_obabel folder not named properly!")
    if not labels[2]:
        raise Exception("r_png folder not named properly")
    if not labels[3]:
        raise Exception("smiles folder not named properly")

    name = ""
    code = ""
    code_flag = False

    folders = getF(p_obabel, "folders")

    for fol in folders:

        current_folder_dir = p_obabel + fol + "/"
        files = getF(current_folder_dir, "files")

        for fil in files:

            current_file_path = current_folder_dir + fil
            cor_out_folder = r_png + fol + "/"

            # read log
            # if logs folder not present then make one
            dir_check(root + "logs" + "/" + "png_maker/")
            logs_path = root + "logs" + "/" + "png_maker" + "/" + "c_logs.txt"
            file_if_not(logs_path)
            logs_dict = read_dict(logs_path)

            # call png_maker for this file only if it is not done already
            # parser
            # if folder is in logs file
            # flag for file presence
            file_present = False

            if fol in logs_dict:
                # check whether file(i) is in it or not
                for i in logs_dict[fol]:
                    # if file found then continue
                    if i == fil:
                        file_present = True
                        continue
                if not file_present:
                    png_maker(current_file_path, cor_out_folder)
                    # after parsing done, record in logs
                    ap_dict(logs_path, fol, fil, 1)
            else:
                # print("folder not there")
                png_maker(current_file_path, cor_out_folder)
                ap_dict(logs_path, fol, fil, 0)


def splitter(huge_file_path, out_folder4pieces):

    # split files into pieces with 50k molecules each
    # close writing when modulo 50k == 0 or when end of file reached
    if out_folder4pieces[-1] != "/":
        out_folder4pieces = out_folder4pieces + "/"

    file_no = 1
    line_no = 0
    piece = ""

    with open (huge_file_path, 'r') as f:
        for line in f:

            # Note: no need to append newline character with the piece as "line" of for loop already has newline character at the end
            piece += line
            line_no += 1

            if line_no%50000 == 0:
                out_file_path = out_folder4pieces + str(file_no) + ".smi"
                file_if_not(out_file_path)
                with open(out_file_path, 'w', encoding="utf-8") as w:
                    w.write(piece)
                    piece = ""
                    file_no += 1
        # possible when file ended but threshold of size not met, so now piece will not be ""
        # SO check, if piece is not "" then write to file,
        # nitpicking : what if file to be read was empty even then piece wil be ""
        # We dont care about that

        if piece != "":

            out_file_path = out_folder4pieces + str(file_no) + ".smi"
            file_if_not(out_file_path)
            with open(out_file_path, 'w', encoding="utf-8") as w:
                w.write(piece)
                piece = ""

def feed_splitter(huge_files_folder, root):
    if huge_files_folder[-1] != "/":
        huge_files_folder = huge_files_folder + "/"
    if root[-1] != "/":
        root = root + "/"

    huge_files_folders_list = getF(huge_files_folder, "folders")
    for fol in huge_files_folders_list:
        # current folder address
        current_folder_dir = huge_files_folder + fol + "/"
        # corresponding out folder for this folder
        corr_out_folder_dir = root + "/" + "smiles" + "/" + fol + "/"
        # files in current folder
        files = getF(current_folder_dir, "files")
        # do parsing of each file
        for fil in files:
            current_file_path = current_folder_dir + fil
            cor_out_folder = root + "/" + "smiles" + "/" + fol + "/"
            dir_check(cor_out_folder)
            dir_check(root + "/" + "logs" + "/" + "splitter" + "/")
            logs_path = root + "logs" + "/" + "splitter" + "/" + "split_logs.txt"
            file_if_not(logs_path)
            logs_dict = read_dict(logs_path)
            file_present = False
            if fol in logs_dict:
                for i in logs_dict[fol]:
                    # if file found then continue
                    if i == fil:
                        file_present = True
                        continue
                        # break should be
                    if not file_present:
                        splitter(current_file_path, cor_out_folder)
                        # after smiles2svg done, record in logs
                        ap_dict(logs_path, fol, fil, 1)

            else:
                # print("folder not there")
                splitter(current_file_path, cor_out_folder)
                ap_dict(logs_path, fol, fil, 0)

# %% [markdown]
# # Some Notes

# %% [markdown]
#       You take two inputs:
#
#                     raw_obabel      : directory where raw babel svg placed
#                     parsed_obabel   : directory where to store parsed and structured obabel svg
#                     r_png           : where to store returned png
#
#
# > Indented block
#
#
#
#
# raw_obabel
#
#
#                             |---a.txt
#         |---------------A---|---b.txt
#         |                   |---x.txt
#         |
#         |
#         |---------------B----(same as A)
#
#
#
#
# **Short:** make one folder  which must contain r_obabe, p_obabel, r_png folders.......
#
#
# **Extra:**
#         get name of all folders in raw_obabel
#         then iteratively enter each folder
#             with in that folder , parse all .txt files and store in parsed_obabel, with the same folder name and file
#             name
#
#
#
#         keep record of all files parsed in log directory
#         so that in case of failure of any file parsing it is not in log file and we can delete its output folder or file
#         cause it will be corrupt
#
#
#
#
#
# **CAVEATS:**
#
#       1-if the file you want to check existence if has a folder with same name(extension in folder name)
#       then file check fails!
#
#       2-Insert content at specific point in text file without needing to copy huge amount of data first
#       and then writing it back
#
#
#
#
#  **NOTES:**
#
#
#     Directory must be like
#       root/p_obabel
#       root/r_obabel
#       root/r_png
#
#
#
#
#     feed_png_maker takes root directory
#     feed_parser takes root directory
#
#     parser parses one file, feed parser make a pipeline and parses every file in every destination folder automatically
#     png_maker convert one entire text file into images, whereas feed_png_maker make a pipeline and make images out of all
#     files in all desired folders
