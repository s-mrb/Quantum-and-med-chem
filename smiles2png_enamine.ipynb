# %% [markdown]
# **Setup conda envirinment and instal packages**

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !time bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit
# !time conda install -q -y -c openbabel openbabel

# %% [markdown]
# **to make system (this notebook) to see things you just installed, add their path**

# %%
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# %% [markdown]
# **Now you can easily import whatever you installed using conda**

# %%
import openbabel

# %%
import pybel
from pybel import Outputfile
from pybel import readfile

# %% [markdown]
# **Install package which is used to make png**

# %%
# !pip install cairosvg

# %%
from cairosvg import svg2png

# %%
import cairosvg

# %% [markdown]
# **Methods mentioned from last cell upto NOTE above might not work,
# but below one will work**

# %% [markdown]
# **NOTE**
#
#
#       if you installed openbabel, then cairosvg automatically gets insalled, as it is one of the dependency.
#
#       You can not now just say, *from cairosvg import svg2png*. First import cairosvg from installed packages then say *from cairosvg import svg2png*
#
#       It is possible that it still dont works, then use pip to insatll cairosvg

# %%
# !time pip install cairosvg

# %% [markdown]
# **Mount drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Data Download**

# %%
# variables setup
url = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_01.zip"
where_to_store = "/content/drive/My Drive/DataSets/Chemistry/enamine/dwnload"

# %%
# now download data
# !wget "$url" -P "$where_to_store"

# %% [markdown]
# **Unzip in case of zip, untar if tar file**

# %%
# variable setup
# absolute path, uptill extension
zip_file_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/dwnload/Enamine_REAL_full_smiles_Part_01.zip"

# just folder absolute path
where_to_unzip = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip"

# %%
# now unzip
# !unzip -uq "$zip_file_path" -d "$where_to_unzip"

# %% [markdown]
# **See extractd file structure**

# %%
import sys
file_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip/2019q3-4_Enamine_REAL_1.2B_SMILES_Part_01.smiles"

line_no = 0
with open(file_path, 'r') as f:
  for line in f:
    print(line)
    line_no += 1
    if line_no == 50:
      sys.exit()

# %% [markdown]
# **As you can see header must be removed**
#
# First remove header and see whether obabel works on it wihtout any processing on it

# %%
# variabel setup 
# make sure every path vends with /, if not file
out_smiles_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/smiles/one/"
in_smile_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip/one.smiles"

out_file_name = "one.smi"
 
full_out_smiles_path = out_smiles_path + out_file_name

# %% [markdown]
# **Check whther just skipping line and present format works??**

# %%
# first lets check whether can obabel make svg without changing smiles file
out_svg_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/r_obabel/one/"

out_file = Outputfile("svg", out_svg_path + "one.svg")

header = True
for mol in readfile("smi", in_smile_path):

  if header:
    header = False
    continue

  out_file.write(mol)
    
out_file.close()

# %%
# In case obabel not working with this file, make a file with just smiles

# %% [markdown]
# **Parse extracted file, present format might not be usable**
#
# Parse according to ur downloaded smiles files structures, sometimes there won't be any need for doing any pre-processing and you can just feed it to svg maker, All smiles files have smiles in start of line, if parsing is needed just get first string of each line

# %%
# variabel setup 
# make sure every path vends with /, if not file
out_smiles_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/smiles/one/"
in_smiles_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip/one.smiles"

out_file_name = "one.smi"
out_smiles_abs_path = out_smiles_path + out_file_name


dir_check(out_smiles_path)
file_if_not(full_out_smile_path)


with open(in_smiles_path,'r') as r:
  with open(out_smiles_abs_path,'w') as o:
    next(r)
    for line in r:
      o.write(line.split()[0]+"\n")

# %% [markdown]
# **Open file to see format**

# %%
import sys
read_path = out_smiles_abs_path


line_counter = 0
with open (read_path,'r') as f:
  for line in f:
    print(line)
    line_counter += 1

    if line_counter == 500:
      sys.exit()
# Out:
# O=C1C(=CC2=CC=CC=N2)SC(=S)N1C1=CC=CC=C1
#
# CC(C)N1C(C2=CC(C(N)=O)=CO2)=CSC1=NC1=CC=CC=C1
#
# CC1=C(C2=CSC(=NC3=CC=CC=C3)N2C(C)C)C=C(C(N)=O)O1
#
# COC1=CC=CC=C1NC(=O)CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NC1=CC([N+](=O)[O-])=CC=C1
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NC1=CC=CC=C1
#
# CC1=CC=C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CC3=CC=CO3)C2=O)C=C1
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NC1=CC=C(F)C=C1
#
# COC1=CC=C(OC)C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CC3=CC=CO3)C2=O)=C1
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NC1=CC=CC=C1F
#
# CC(=O)C1=CC=C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CC3=CC=CO3)C2=O)C=C1
#
# COC1=CC=C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CC3=CC=CO3)C2=O)C([N+](=O)[O-])=C1
#
# COC1=CC([N+](=O)[O-])=CC=C1NC(=O)CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O
#
# CC1=CC=C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CC3=CC=CO3)C2=O)C([N+](=O)[O-])=C1
#
# COC1=CC=C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CC3=CC=CO3)C2=O)C(OC)=C1
#
# COC1=CC=C([N+](=O)[O-])C=C1NC(=O)CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O
#
# CC1=CC=CC=C1NC(=O)CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NC1=CC=C(F)C=C1F
#
# COC1=CC=C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CC3=CC=CO3)C2=O)C=C1OC
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NCC1=CC=CC=C1
#
# COC1=CC=CC(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CC3=CC=CO3)C2=O)=C1
#
# CCOC1=CC=C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CC3=CC=CO3)C2=O)C=C1
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NC1=CC=C(C(=O)O)C=C1
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NC1CC1
#
# CNC(=O)CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O
#
# CN(C)C1=CC=C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CC3=CC=CO3)C2=O)C=C1
#
# CC1=CC(C(=O)O)=CC=C1NC(=O)CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O
#
# N#CC1=CC=C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CC3=CC=CO3)C2=O)C=C1
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NC1=CC(O)=CC=C1
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NC1=CN=CC=N1
#
# CN(C)CCNC(=O)CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O
#
# CN(C)CCCNC(=O)CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NCCCO
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NCCOCCO
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=CO2)C1=O)NCC(F)(F)F
#
# COC1=CC=CC=C1NC(=O)CC1SC(=NC2=CC=CC=C2)N(CC2=CC=C3OCOC3=C2)C1=O
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC2=CC=C3OCOC3=C2)C1=O)NC1=CC=CC=C1
#
# O=C(CC1SC(=NC2=CC=CC=C2)N(CC
# COCCCN1C(C2=C(C)ON=C2C)=CSC1=NC1=CC=CC=C1
#
# COCCCN1C(C2=CC3=C(CCN(C(C)=O)C3)S2)=CSC1=NC1=CC=CC=C1
#
# COCCCN1C(C2=CC=C(S(C)(=O)=O)N=C2)=CSC1=NC1=CC=CC=C1
#
# COCCCN1C(C2=NN(C)N=C2)=CSC1=NC1=CC=CC=C1
#
# COCCCN1C(C2=CN=NN2C)=CSC1=NC1=CC=CC=C1
#
# COCCCN1C(C2=CN(C)N=N2)=CSC1=NC1=CC=CC=C1
#
# COC1=CC=CC=C1NC(=O)CC1SC(=NC2=CC=CC=C2)N(CCC(C)C)C1=O
#
# COC1=CC=C(OC)C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CCC(C)C)C2=O)=C1
#
# CC(C)CCN1C(=O)C(CC(=O)NC2=CC=CC=C2F)SC1=NC1=CC=CC=C1
#
# CC(=O)C1=CC=C(NC(=O)CC2SC(=NC3=CC=CC=C3)N(CCC(C)C)C2=O)C=C1
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# **Test svg maker now**

# %%
# first lets check whether can obabel make svg without changing smiles file
in_smiles_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip/one.smiles"
out_svg_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/r_obabel/one/"
out_svg_name = "one.svg"

svg_abs_path = out_svg_path + out_svg_name
out_file = Outputfile("svg", out_svg_path + "one.svg")

header = True
for mol in readfile("smi", in_smile_path):
  out_file.write(mol)
    
out_file.close()

# %% [markdown]
# **checking unix command**

# %%
file_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/unzip/one.smiles"
out_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/r_obabel/one/"
name = "one.svg"

full_p = out_path + name

# !babel -ismi "$file_path" -osvg out_path
# Out:
# 0 molecules converted
# 5 audit log messages

# %% [markdown]
# **Still not working?? make a small file out of the same file and see whether problem is due to huge file size??**

# %%
import sys

read_p =  "/content/drive/My Drive/DataSets/Chemistry/enamine/root/smiles/one/one.smi"
out_name = "one_small.smi"
out_dir = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/smiles/one_smal/"
out_p   =  "/content/drive/My Drive/DataSets/Chemistry/enamine/root/smiles/one_smal/" + out_name

dir_check(out_dir)
file_if_not(out_p)


line_no = 0
with open(read_p , 'r') as r:
  with open(out_p,'w') as w:
    for line in r:
      w.write(line)
      line_no += 1

      if line_no == 5:
        sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# **Now test svg maker again**

# %%
# first lets check whether can obabel make svg without changing smiles file
in_smiles_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/smiles/one_smal/one_small.smi"
out_svg_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/r_obabel/one_small/"
out_svg_name = "one.svg"

svg_abs_path = out_svg_path + out_svg_name
out_file = Outputfile("svg", out_svg_path + "one.svg")

for mol in readfile("smi", "in_smile_path"):
  out_file.write(mol)
    
out_file.close()

# %% [markdown]
# **Still error???????????**
#
# Try gdb smi to test difference of format

# %%
# first lets check whether can obabel make svg without changing smiles file
in_smiles_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/smiles/one_gdb/gdb11_size02.smi"
out_svg_path = "/content/drive/My Drive/DataSets/Chemistry/enamine/root/r_obabel/one_gdb/"
out_svg_name = "one_gdb.svg"

svg_abs_path = out_svg_path + out_svg_name
out_file = Outputfile("svg", "/content/drive/My Drive/DataSets/Chemistry/enamine/root/r_obabel/one_gdb/"+"oh_gdb.svg")

for mol in readfile("smi", "/content/par/one.smi"):
  out_file.write(mol)
    
out_file.close()

# %%
# !unzip -uq "/content/drive/My Drive/DataSets/Chemistry/enamine/dwnload/Enamine_REAL_full_smiles_Part_01.zip" -d "/content/k"

# %%
# !cp "/content/drive/My Drive/DataSets/Chemistry/root/smiles/one/one.smi" "/content/par"
# Out:
# cp: cannot stat '/content/drive/My Drive/DataSets/Chemistry/root/smiles/one/one.smi': No such file or directory

# %% [markdown]
# **check the newly created file**

# %%
import sys

line_no = 0
with open (full_out_path, 'r') as f:
  for line in f:
    print (line)
    line_no += 1
    if line_no == 50:
      sys.exit()

# %% [markdown]
# **ALL the Methods**
#
#
# ***NOTE:***
#
#       In local PC path convention differs from that of colab,  / vs \

# %%
import ntpath
from os import walk, path
from pathlib import Path
import os
import sys





def feed_obabel(in_smile_path,out_svg_path):
  out_file = Outputfile("svg", out_svg_path)
  for mol in readfile("smi", in_smile_path):
    out_file.write(mol)
    
  out_file.close()




# define smiles feeder

def feed_smiles(root):

    if root[-1] != "/":
      root += "/"
    folders = getF(root, "folders")


    # g = getF(root + "\\" + folders[2])

    if len(folders) == 0:
        raise Exception("Empty directory!")

    if len(folders) == 1:
        raise Exception("One folders missing!")

    if len(folders) == 2:
        raise Exception("Two folders missing!")
    if len(folders) == 3:
        raise Exception("Three folders missing!")

    r_obabel = ""
    r_png = ""
    p_obabel = ""
    smiles = ""

    flag = {"r_obabel": 0, "p_obabel": 0, "r_png": 0, "smiles":0}

    for f in folders:
        if f == "r_obabel":
            r_obabel = root + f + "/"
            flag["r_obabel"] = 1
        if f == "p_obabel":
            p_obabel = root + f + "/"
            flag["p_obabel"] = 1
        if f == "r_png":
            r_png = root + f + "/"
            flag["r_png"] = 1
        if f == "smiles":
            smiles = root + f + "/"
            flag["smiles"] = 1
        

    labels = list(flag.values())

    name = ""

    if not labels[0]:
        raise Exception("r_obabel folder not named properly!")
    if not labels[1]:
        raise Exception("p_obabel folder not named properly!")
    if not labels[2]:
        raise Exception("r_png folder not named properly")
    if not labels[3]:
        raise Exception("smiles folder not named properly")

    # Reading smiles directory

    smiles_folders = getF(smiles, "folders")

    # Read
    for fol in smiles_folders:

        # current folder address
        current_folder_dir = smiles + fol + "/"

        # corresponding out folder for this folder
        corr_out_folder_dir = r_obabel + fol + "/"

        # files in current folder
        
        files = getF(current_folder_dir, "files")
    

        # do parsing of each file
        for fil in files:

            # complete path of current file
            file_path = current_folder_dir + fil

            dir_check(corr_out_folder_dir)

            # corresponding out file path
            # before passing file to parser make output folder if don't exist
            out_path = corr_out_folder_dir + fil

            # read log
            # if logs folder not present then make one
            dir_check(root + "logs" + "/" + "smiles_feeder/")
            logs_path = root + "logs" + "/" + "smiles_feeder" + "/" + "sf_logs.txt"
            file_if_not(logs_path)
            logs_dict = read_dict(logs_path)

            # call feed_obabel for this file only if it is not feeded already

            # if folder is in logs file
            # flag for file presence
            file_present = False

            if fol in logs_dict:
                # check whether file(i) is in it or not
                for i in logs_dict[fol]:
                    # if file found then continue
                    if i == fil:
                        file_present = True
                        continue
                if not file_present:
                    feed_obabel(file_path, out_path)
                    # after smiles2svg done, record in logs
                    ap_dict(logs_path, fol, fil, 1)
            else:
                # print("folder not there")
                feed_obabel(file_path, out_path)
                ap_dict(logs_path, fol, fil, 0)





def dir_check(path):
    Path(path).mkdir(parents=True, exist_ok=True)

# 2nd way
# def dir_check(path):
#     if not os.path.exists(path):
#         os.makedirs(path)


# here read_dict is used to read log files, make sure to keep all logs
# with same format so that you can reuse this function
def read_dict(path):
    dic = {}
    with open(path,'r') as f:
        key = ""
        for line in f:
            if line[0:5] == "_key_":
                key = (line.split())[1]
            else:
                temp = {key:line.split()}
                dic.update(temp)
        return dic

    # for line in file:
    #     line_offset.append(offset)
    #     offset += len(line)


def get_append_pos(path, key):
    with open(path,'r') as f:
        while True:
            # read line and move cursor to start of next line, but could be read in next while loop!!
            line = f.readline()

            if line == '':
                break
            if line[0:5] == "_key_":
                if (line.split())[1] == key:
                    # move cursor to start of **line after next line**,
                    # print()
                    f.readline()

                    # Why -1 works????
                    #
                    # The newline character is a single(typically 8 - bit) character.It's represented in program source
                    # (either in a character literal or in a string literal) by the two-character sequence \n . So '\n
                    # ' is a character constant representing a single character, the newline character

                    return f.tell() - 1
    return


def ap_dict(path, key, value, folder):
    # folder is boolean, 0 if key absent else 1
    if folder == 0:
        with open(path, 'a') as f:
            f.write("\n_key_ " + key + "\n" + value +" ")
            return
    pos = get_append_pos(path, key)

    c_last = ""

    with open (path, 'r') as f:
        f.seek(pos)
        c_last = f.read()

    # Note you can not use append below because
    # cause if first time if it is
    # _key_   gdb_11_2
    # gdb_11_2.txt
    #
    # then second time it will be
    # gdb_11_2.txt    gdb_11_3.txt    gdb_11_2.txt
    #
    # Why, because you r keeping line number to copy rest but using seek to write, so if you want to use append
    # then keep record of posiiton of index where to append
    #
    with open(path, 'a') as f:

        f.seek(pos)
        f.write(value + " " + c_last)



def file_if_not(p):
    if not os.path.exists(p):
        open(p, 'a').close()


def getF(directory, x="both"):
    # x could be "files" or "folders" or "both"

    folders = []
    for f in walk(directory):
        folders.extend(f)

    if x == "folders":

      return folders[1]
      
        
    if x == "files":
        return folders[2]
    else:
      return folders[1], folders[2]

      
        
        


def path_leaf(path):
    head, tail = ntpath.split(path)

    # if name ends with \\ then tail won't return anything
    # return tail or ntpath.basename(head)

    # since you dont want to return in case its not file
    return tail

def parse_r_obabel(read_path, write_path):
    # Parser for babel svg

    # NOTE below string also include \n, to add \n at end you must enter on last line
    start = """<svg version="1.1" id="topsvg"
    xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
    xmlns:cml="http://www.xml-cml.org/schema" x="0" y="0" width="256" height="256" viewBox="0 0 100 100">
    <title> - Open Babel Depiction</title>
    <rect x="0" y="0" width="100" height="100" fill="white"/>
    <g transform="translate(0,0)">
    """

    fil = 'fill="rgb(0,0,0)"'
    strke = 'stroke="rgb(0,0,0)"'
    strke_width = 'stroke-width="1"'

    # NOTE : anything added to above str is added on new line



    st = ""
    out = ""
    smile_done = False
    end = False
    finish = False
    space = " "
    width = 'width="100"'
    height = 'height="100"'

    test_c = 0
    dim_flag = False
    b_check = False
    s_check = False

    file = path_leaf(read_path)

    with open(read_path, 'r', encoding="utf-8") as f:
        for i in range(1):
            next(f)
        for line in f:
            if line[1:5] == "?xml":
              continue

            if line[1:12] == "svg version":
                for i in range(5):
                    next(f)
                continue
            if line[0:4] == "</g>" or end:

                end = True

                line_split = line.split()
                for token in line_split:
                    if token[0] == ">":
                        id = "db: " + file + " id: " + token[1:]
                        st = st + "</g>" + "\n" + "</svg>" + "\n"
                        st = id + "\n" + '"""' + "\n" + start + st + '"""' + "\n"
                        out = out + st
                        st = ""
                        smile_done = True
                        end = False

            if end:
                continue

            if smile_done:
                if not end:
                    smile_done = False
                    finish = True
                    continue
            if finish:
                finish = False

                continue

            token_list = []
            for s in line.split():
                if s[-1] == ">":
                    b_check = True

                if (2 <= len(s)):
                    if s[-2] == "/":
                        s_check = True

                if s[0:6] == "width=":
                    s = width
                if s[0:7] == "height=":
                    s = height
                if s[0:7] == "stroke=":
                    s = strke
                if s[0:13] == "stroke-width=":
                    s = strke_width
                if s[0:5] == "fill=":
                    s = fil
                if b_check:
                    b_check = False
                    if s_check:
                        s_check = False
                        if s[-2] != "/":
                            s = s + "/>"
                    elif s[-1] != ">":
                        s = s + ">"

                token_list.append(s)

            temp = ""
            for t in range(len(token_list) - 1):
                temp += token_list[t] + " "

            # sometimes list will  be empty
            if token_list:
                temp += token_list[-1] + "\n"

            token_list = []

            st = st + temp

    with open(write_path, 'w') as f:
        f.write(out)

# parse raw svg of obabel into form receivable to svg2png converter
def feed_parser(root):

    if root[-1] != "/":
      root += "/"
    folders = getF(root, "folders")


    # g = getF(root + "\\" + folders[2])

    if len(folders) == 0:
        raise Exception("Empty directory!")

    if len(folders) == 1:
        raise Exception("One folders missing!")

    if len(folders) == 2:
        raise Exception("Two folders missing!")
    if len(folders) == 3:
        raise Exception("Three folders missing!")

    r_obabel = ""
    r_png = ""
    p_obabel = ""
    smiles = ""

    flag = {"r_obabel": 0, "p_obabel": 0, "r_png": 0, "smiles":0}

    for f in folders:
        if f == "r_obabel":
            r_obabel = root + f + "/"
            flag["r_obabel"] = 1
        if f == "p_obabel":
            p_obabel = root + f + "/"
            flag["p_obabel"] = 1
        if f == "r_png":
            r_png = root + f + "/"
            flag["r_png"] = 1
        if f == "smiles":
            smiles = root + f + "/"
            flag["smiles"] = 1           

        

    labels = list(flag.values())

    name = ""

    if not labels[0]:
        raise Exception("r_obabel folder not named properly!")
    if not labels[1]:
        raise Exception("p_obabel folder not named properly!")
    if not labels[2]:
        raise Exception("r_png folder not named properly")
    if not labels[3]:
        raise Exception("smiles folder not named properly")

    # Reading r_obabel

    r_obabel_folders = getF(r_obabel, "folders")

    # Read
    for fol in r_obabel_folders:

        # current folder address
        current_folder_dir = r_obabel + fol + "/"

        # corresponding out folder for this folder
        corr_out_folder_dir = p_obabel + fol + "/"

        # files in current folder
        
        files = getF(current_folder_dir, "files")
    

        # do parsing of each file
        for fil in files:

            # complete path of current file
            file_path = current_folder_dir + fil

            dir_check(corr_out_folder_dir)

            # corresponding out file path
            # before passing file to parser make output folder if don't exist
            out_path = corr_out_folder_dir + fil

            # read log
            # if logs folder not present then make one
            dir_check(root + "logs" + "/" + "parser/")
            logs_path = root + "logs" + "/" + "parser" + "/" + "p_logs.txt"
            file_if_not(logs_path)
            logs_dict = read_dict(logs_path)

            # call parser for this file only if it is not parsed already
            # parser
            # if folder is in logs file
            # flag for file presence
            file_present = False

            if fol in logs_dict:
                # check whether file(i) is in it or not
                for i in logs_dict[fol]:
                    # if file found then continue
                    if i == fil:
                        file_present = True
                        continue
                if not file_present:
                    parse_r_obabel(file_path, out_path)
                    # after parsing done, record in logs
                    ap_dict(logs_path, fol, fil, 1)
            else:
                # print("folder not there")
                parse_r_obabel(file_path, out_path)
                ap_dict(logs_path, fol, fil, 0)






def png_maker(current_file_path, cor_out_folder):
  
    input = current_file_path

    name = ""
    code = ""
    code_flag = False

    with open(current_file_path, 'r') as smiles:
        for line in smiles:
            if line[0:3] == "db:":
                tok = line.split()
                db = tok[1].split('.')[0]
                no = tok[3]
                name = db + "_" + no
                continue

            if line[0:3] == '"""':
                if code_flag:
                    code_flag = False

                    dir_check(cor_out_folder)
                    svg2png(bytestring=code,
                            write_to=cor_out_folder + name + ".png")

                    code = ""
                    name = ""
                    continue

            if line[0:3] == '"""':
                code_flag = True
                continue

            if code_flag:
                code += line




def feed_png_maker(root):

    if root[-1] != "/":
      root += "/"
    folders = getF(root, "folders")
    g = getF(root + "/" + folders[2])

    if len(folders) == 0:
        raise Exception("Empty directory!")

    if len(folders) == 1:
        raise Exception("Three folders missing!")

    if len(folders) == 2:
        raise Exception("two folders missing!")
    if len(folders) == 3:
        raise Exception("One folders missing!")

    r_obabel = ""
    r_png = ""
    p_obabel = ""
    smiles = ""

    flag = {"r_obabel": 0, "p_obabel": 0, "r_png": 0, "smiles":0}

    for f in folders:
        if f == "r_obabel":
            r_obabel = root + f + "/"
            flag["r_obabel"] = 1
        if f == "p_obabel":
            p_obabel = root + f + "/"
            flag["p_obabel"] = 1
        if f == "r_png":
            r_png = root + f + "/"
            flag["r_png"] = 1
        if f == "smiles":
            smiles = root + f + "/"
            flag["smiles"] = 1


    labels = list(flag.values())

    name = ""

    if not labels[0]:
        raise Exception("r_obabel folder not named properly!")
    if not labels[1]:
        raise Exception("p_obabel folder not named properly!")
    if not labels[2]:
        raise Exception("r_png folder not named properly")
    if not labels[3]:
        raise Exception("smiles folder not named properly")

    name = ""
    code = ""
    code_flag = False

    folders = getF(p_obabel, "folders")

    for fol in folders:

        current_folder_dir = p_obabel + fol + "/"
        files = getF(current_folder_dir, "files")

        for fil in files:

            current_file_path = current_folder_dir + fil
            cor_out_folder = r_png + fol + "/"

            # read log
            # if logs folder not present then make one
            dir_check(root + "logs" + "/" + "png_maker/")
            logs_path = root + "logs" + "/" + "png_maker" + "/" + "c_logs.txt"
            file_if_not(logs_path)
            logs_dict = read_dict(logs_path)

            # call png_maker for this file only if it is not done already
            # parser
            # if folder is in logs file
            # flag for file presence
            file_present = False

            if fol in logs_dict:
                # check whether file(i) is in it or not
                for i in logs_dict[fol]:
                    # if file found then continue
                    if i == fil:
                        file_present = True
                        continue
                if not file_present:
                    png_maker(current_file_path, cor_out_folder)
                    # after parsing done, record in logs
                    ap_dict(logs_path, fol, fil, 1)
            else:
                # print("folder not there")
                png_maker(current_file_path, cor_out_folder)
                ap_dict(logs_path, fol, fil, 0)

# %% [markdown]
# Get root directory
#
#   Directory must be like
#
#
#       root/p_obabel
#       root/r_obabel
#       root/r_png

# %%
root = '/content/drive/My Drive/DataSets/Chemistry/root'

# %% [markdown]
# **If you do not have smiles then first download them**

# %% [markdown]
# **Feed Parser Or PNG MAKER**
#
# changes needed to be done, so that both could run simultaneously, without feeding one first then other

# %%
# feed_smiles(root)
# feed_parser(root)
# feed_png_maker(root)


# takes half an hour for gdb_11_8, png making

# %%
# Debug
fold = '/content/drive/My Drive/DataSets/Chemistry/root'
files = getF(fold,"files")
files
# Out:
# []

# %% [markdown]
# **Count files**

# %%
folder = '/content/drive/My Drive/DataSets/Chemistry/obabel2png/r_png/gdb_11'

# %%
files = []
for all in walk(folder):
  files.extend(all)

# print(files)
print(len(files[2]))
# Out:
# 79584

# %% [markdown]
# **Some Notes**
#
#
#       You take two inputs:
#
#                     raw_obabel      : directory where raw babel svg placed
#                     parsed_obabel   : directory where to store parsed and structured obabel svg
#                     r_png           : where to store returned png
#
#
#
# raw_obabel
#
#
#                             |---a.txt
#         |---------------A---|---b.txt
#         |                   |---x.txt
#         |
#         |
#         |---------------B----(same as A)
#
#
#
#
# **Short:** make one folder  which must contain r_obabe, p_obabel, r_png folders.......
#
#
# **Extra:**
#         get name of all folders in raw_obabel
#         then iteratively enter each folder
#             with in that folder , parse all .txt files and store in parsed_obabel, with the same folder name and file
#             name
#
#
#
#         keep record of all files parsed in log directory
#         so that in case of failure of any file parsing it is not in log file and we can delete its output folder or file
#         cause it will be corrupt
#
#
#
#
#
# **CAVEATS:**
#
#       1-if the file you want to check existence if has a folder with same name(extension in folder name)
#       then file check fails!
#
#       2-Insert content at specific point in text file without needing to copy huge amount of data first
#       and then writing it back
#
#
#
#
#  **NOTES:**
#
#
#     Directory must be like
#       root/p_obabel
#       root/r_obabel
#       root/r_png
#
#
#
#
#     feed_png_maker takes root directory
#     feed_parser takes root directory
#
#     parser parses one file, feed parser make a pipeline and parses every file in every destination folder automatically
#     png_maker convert one entire text file into images, whereas feed_png_maker make a pipeline and make images out of all
#     files in all desired folders
